# %% [markdown]
# # Agro-environmental regions in Ireland
#
# Agro-environmental regions described in Holden and Brereton (2004) derived
# from February rainfall data
#
# A screenshot of the map in the paper was taken and georeferenced into vector
# data
#
# Holden, N. M. and Brereton, A. J. (2004). 'Definition of agroclimatic regions
# in Ireland using hydro-thermal and crop yield data', Agricultural and Forest
# Meteorology, vol. 122, no. 3, pp. 175-191. DOI:
# [10.1016/j.agrformet.2003.09.010][DOI].
#
# [DOI]: https://doi.org/10.1016/j.agrformet.2003.09.010

# %%
# import libraries
import os
from datetime import datetime, timezone
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
print("Last updated:", datetime.now(tz=timezone.utc))
# Out:
# Last updated: 2022-10-16 01:11:54.050586+00:00

# %%
# define data path
DATA_DIR = os.path.join(
    "data",
    "climatic-regions",
    "agro-environmental-regions",
    "agro-environmental-regions.gpkg"
)

# %%
data = gpd.read_file(DATA_DIR, layer="agro-environmental-regions")

# %%
data
# Out:
#   Region Cluster                      Regions  \
# 0      5       5                  West Ulster
# 1    3,4   3 & 4               Central Ulster
# 2      7       7           Northwest Connacht
# 3      2       2             Central Connacht
# 4      1       1  East Ulster & East Leinster
# 5      6       6    South & Southwest Munster
#
#                                              Climate  \
# 0  Cool temperatures (<8.5 deg C); relatively wet...
# 1  Cluster 3: Moderate temperatures (8.5-9.0 deg ...
# 2  Moderate temperatures (~9.0 deg C); wet rainfa...
# 3  Moderate temperatures (8.5-9.0 deg C); average...
# 4  Warm temperatures (~9.5 deg C); relatively dry...
# 5  Warm temperatures (9.5-10.0 deg C); relatively...
#
#                                                Grass  \
# 0  Poor grass yield; some growing season limitations
# 1  Cluster 3: Poor to moderate grass yield; some ...
# 2                                   Good grass yield
# 3  Moderate to good grass yield; average conditio...
# 4                              Water stress in grass
# 5                                   Good grass yield
#
#                                             geometry
# 0  MULTIPOLYGON (((-8.51064 54.28134, -8.51028 54...
# 1  MULTIPOLYGON (((-8.59627 54.22292, -8.59609 54...
# 2  MULTIPOLYGON (((-10.31356 53.60068, -10.31360 ...
# 3  MULTIPOLYGON (((-10.22229 53.39345, -10.22229 ...
# 4  MULTIPOLYGON (((-5.80333 54.82402, -5.80314 54...
# 5  MULTIPOLYGON (((-10.54655 51.76489, -10.54665 ...

# %%
data.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
data.shape
# Out:
# (6, 6)

# %%
ax = data.plot(
    column="Cluster",
    legend=True,
    figsize=(9, 9),
    cmap="Set3",
    legend_kwds=dict(loc="upper left")
)


def longitude(x, pos):
    """The two arguments are the value and tick position."""
    return "{:,.0f}°W".format(x * -1)


ax.xaxis.set_major_formatter(longitude)
ax.yaxis.set_major_formatter("{x}°N")

data.boundary.plot(ax=ax, color="darkslategrey", linewidth=.5)

plt.title(
    "Agro-environmental regions in Ireland [Holden and Brereton (2004)]"
)
# plt.xlabel("Longitude")
# plt.ylabel("Latitude")
plt.show()
