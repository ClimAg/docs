# %% [markdown]
# # Annual/overall stats - HiResIreland - Difference in (weighted) mean - historical and rcp45/rcp85
#
# - Weighted means take into account the number of days in each month

# %%
# import libraries
from datetime import datetime, timezone
import climag.plot_stats as cstats
import importlib

# %%
season_list = ["DJF", "MAM", "JJA", "SON"]

# %%
data = cstats.hist_rcp_stats_data(
    dataset="HiResIreland", stat="mean", annual=True
)

# %%
importlib.reload(cstats)
# Out:
# <module 'climag.plot_stats' from '/run/media/nms/Backup/Documents/Git/ClimAg/ClimAg/climag/plot_stats.py'>

# %% [markdown]
# ## Total growth (daily)

# %%
cstats.plot_all(
    data=data["HiResIreland_s"],
    var="gro",
    season=None,
    levels=cstats.colorbar_levels(6),
    ticks=cstats.colorbar_ticks(6),
)
# Out:
# ________________________________________________________________________________
# Difference in average total growth
# ________________________________________________________________________________

# %% [markdown]
# ## Potential growth (daily)

# %%
cstats.plot_all(
    data=data["HiResIreland_s"],
    var="pgro",
    season=None,
    levels=cstats.colorbar_levels(10),
    ticks=cstats.colorbar_ticks(10),
)
# Out:
# ________________________________________________________________________________
# Difference in average potential growth
# ________________________________________________________________________________

# %% [markdown]
# ## Total ingestion (daily)

# %%
cstats.plot_all(
    data=data["HiResIreland_s"],
    var="c_bm",
    season=None,
    levels=cstats.colorbar_levels(2.4),
    ticks=cstats.colorbar_ticks(2.4),
)
# Out:
# ________________________________________________________________________________
# Difference in average ingested biomass
# ________________________________________________________________________________

# %% [markdown]
# ## Standing biomass (cumulative)

# %%
cstats.plot_all(
    data=data["HiResIreland_s"],
    var="bm",
    season=None,
    levels=cstats.colorbar_levels(400),
    ticks=cstats.colorbar_ticks(400),
)
# Out:
# ________________________________________________________________________________
# Difference in average standing biomass
# ________________________________________________________________________________

# %% [markdown]
# ## Defoliation (senescence + abscission) (daily)

# %%
cstats.plot_all(
    data=data["HiResIreland_s"],
    var="sen_abs",
    season=None,
    levels=cstats.colorbar_levels(7.5),
    ticks=cstats.colorbar_ticks(7.5),
)
# Out:
# ________________________________________________________________________________
# Difference in average defoliation
# ________________________________________________________________________________

# %% [markdown]
# ## Total biomass consumption (ingested + harvested) (yearly total)

# %%
cstats.plot_all(
    data=data["HiResIreland_c"],
    var="c_bm_all",
    season=None,
    levels=cstats.colorbar_levels(750),
    ticks=cstats.colorbar_ticks(750),
)
# Out:
# ________________________________________________________________________________
# Difference in average yearly ingested and harvested biomass
# ________________________________________________________________________________

# %%
print("Last updated:", datetime.now(tz=timezone.utc))
# Out:
# Last updated: 2023-04-18 17:28:32.231861+00:00
