# %% [markdown]
# # intake-esm
#
# - <https://data-infrastructure-services.gitlab-pages.dkrz.de/tutorials-and-use-cases>
# - <https://gitlab.dkrz.de/data-infrastructure-services/intake-esm/>
# - <https://intake-esm.readthedocs.io/>
# - <https://github.com/intake/intake-esm>
# - <https://gallery.pangeo.io/repos/pangeo-data/pangeo-tutorial-gallery/intake.html>
# - <https://intake.readthedocs.io/>

# %%
# import libraries
import json
import os
from datetime import datetime, timezone
import geopandas as gpd
import intake
import matplotlib.pyplot as plt
import xarray as xr
import climag.plot_configs as cplt
from climag.download_data import download_data

# %%
print("Last updated:", datetime.now(tz=timezone.utc))
# Out:
# Last updated: 2022-10-18 13:32:24.459153+00:00

# %%
DATA_DIR_BASE = os.path.join("data", "eurocordex")

# %%
os.makedirs(DATA_DIR_BASE, exist_ok=True)

# %%
# Cork Airport met station coords
LON = -8.48611
LAT = 51.84722

# %%
# Ireland boundary
GPKG_BOUNDARY = os.path.join("data", "boundary", "boundaries.gpkg")
ie = gpd.read_file(GPKG_BOUNDARY, layer="NUTS_Ireland_ITM")

# %%
timerange = [
    "19760101-19801231",
    "19810101-19851231",
    "19860101-19901231",
    "19910101-19951231",
    "19960101-20001231",
    "20010101-20051231",
    "20410101-20451231",
    "20460101-20501231",
    "20510101-20551231",
    "20560101-20601231",
    "20610101-20651231",
    "20660101-20701231"
]

# %%
# add additional time ranges for the MOHC datasets
timerange = timerange + [t.replace("1231", "1230") for t in timerange]

# %%
variables = ["evspsblpot", "mrso", "pr", "rsds", "tas"]

# %%
driving_model_id = [
    "CNRM-CERFACS-CNRM-CM5",
    "ICHEC-EC-EARTH",
    "MPI-M-MPI-ESM-LR",
    "MOHC-HadGEM2-ES"
]

# %% [markdown]
# ## Create local catalogue

# %%
dkrz_cat = intake.open_catalog(["https://dkrz.de/s/intake"])

# %%
server = dkrz_cat._entries["dkrz_cordex_disk"]._open_args["esmcol_obj"]

# %%
server
# Out:
# 'https://gitlab.dkrz.de/data-infrastructure-services/intake-esm/-/raw/master/esm-collections/cloud-access/dkrz_cordex_disk.json'

# %%
dkrz_cordex = intake.open_esm_datastore(
    server,
    read_csv_kwargs={"dtype": {"time_min": "string", "time_max": "string"}}
)

# %%
# download JSON catalogue from DKRZ's GitLab
download_data(server=server, dl_dir=DATA_DIR_BASE)
# Out:
# Data successfully downloaded to data/eurocordex
# Last downloaded: 2022-10-12 23:15:29.546805+00:00

# %%
# keep data for the relevant variables and time ranges
query = dict(
    CORDEX_domain="EUR-11",
    experiment_id=["historical", "rcp45", "rcp85"],
    frequency="day",
    variable_id=variables,
    time_range=timerange,
    model_id="SMHI-RCA4",
    driving_model_id=driving_model_id,
    member=["r1i1p1", "r12i1p1"]
)

# %%
cordex_eur11 = dkrz_cordex.search(**query)

# %%
cordex_eur11
# Out:
# <p><strong>dkrz_cordex_disk catalog with 12 dataset(s) from 486 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>project</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>product_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>CORDEX_domain</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>institute_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>driving_model_id</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>experiment_id</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>member</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>model_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>rcm_version_id</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>frequency</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>variable_id</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>version</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>time_range</th>
#       <td>24</td>
#     </tr>
#     <tr>
#       <th>uri</th>
#       <td>486</td>
#     </tr>
#     <tr>
#       <th>institution_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>source_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>simulation_id</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>grid_label</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>grid_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>time_reduction</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>realm</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>level_type</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>time_min</th>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>time_max</th>
#       <td>24</td>
#     </tr>
#     <tr>
#       <th>path</th>
#       <td>486</td>
#     </tr>
#     <tr>
#       <th>format</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>opendap_url</th>
#       <td>486</td>
#     </tr>
#     <tr>
#       <th>derived_variable_id</th>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
cordex_eur11.df.shape
# Out:
# (486, 27)

# %%
list(cordex_eur11.df)
# Out:
# ['project',
#  'product_id',
#  'CORDEX_domain',
#  'institute_id',
#  'driving_model_id',
#  'experiment_id',
#  'member',
#  'model_id',
#  'rcm_version_id',
#  'frequency',
#  'variable_id',
#  'version',
#  'time_range',
#  'uri',
#  'institution_id',
#  'source_id',
#  'simulation_id',
#  'grid_label',
#  'grid_id',
#  'time_reduction',
#  'realm',
#  'level_type',
#  'time_min',
#  'time_max',
#  'path',
#  'format',
#  'opendap_url']

# %%
cordex_eur11.df.head()
# Out:
#   project product_id CORDEX_domain institute_id       driving_model_id  \
# 0  CORDEX     output        EUR-11         SMHI  CNRM-CERFACS-CNRM-CM5
# 1  CORDEX     output        EUR-11         SMHI  CNRM-CERFACS-CNRM-CM5
# 2  CORDEX     output        EUR-11         SMHI  CNRM-CERFACS-CNRM-CM5
# 3  CORDEX     output        EUR-11         SMHI  CNRM-CERFACS-CNRM-CM5
# 4  CORDEX     output        EUR-11         SMHI  CNRM-CERFACS-CNRM-CM5
#
#   experiment_id  member   model_id rcm_version_id frequency  ... grid_label  \
# 0    historical  r1i1p1  SMHI-RCA4             v1       day  ...       None
# 1    historical  r1i1p1  SMHI-RCA4             v1       day  ...       None
# 2    historical  r1i1p1  SMHI-RCA4             v1       day  ...       None
# 3    historical  r1i1p1  SMHI-RCA4             v1       day  ...       None
# 4    historical  r1i1p1  SMHI-RCA4             v1       day  ...       None
#
#   grid_id time_reduction realm level_type  time_min  time_max  \
# 0    None           None  None       None  19760101  19801231
# 1    None           None  None       None  19810101  19851231
# 2    None           None  None       None  19860101  19901231
# 3    None           None  None       None  19910101  19951231
# 4    None           None  None       None  19960101  20001231
#
#                                                 path  format  \
# 0  /work/kd0956/CORDEX/data/cordex/output/EUR-11/...  netcdf
# 1  /work/kd0956/CORDEX/data/cordex/output/EUR-11/...  netcdf
# 2  /work/kd0956/CORDEX/data/cordex/output/EUR-11/...  netcdf
# 3  /work/kd0956/CORDEX/data/cordex/output/EUR-11/...  netcdf
# 4  /work/kd0956/CORDEX/data/cordex/output/EUR-11/...  netcdf
#
#                                          opendap_url
# 0  http://esgf1.dkrz.de/thredds/dodsC/cordex/EUR-...
# 1  http://esgf1.dkrz.de/thredds/dodsC/cordex/EUR-...
# 2  http://esgf1.dkrz.de/thredds/dodsC/cordex/EUR-...
# 3  http://esgf1.dkrz.de/thredds/dodsC/cordex/EUR-...
# 4  http://esgf1.dkrz.de/thredds/dodsC/cordex/EUR-...
#
# [5 rows x 27 columns]

# %%
# drop v1 of MPI-M-MPI-ESM-LR outputs
cordex_eur11_df = cordex_eur11.df.drop(
    cordex_eur11.df[
        (cordex_eur11.df["driving_model_id"] == "MPI-M-MPI-ESM-LR") &
        (cordex_eur11.df["rcm_version_id"] == "v1")
    ].index
)

# %%
# keep only r12i1p1 outputs of ICHEC-EC-EARTH
cordex_eur11_df = cordex_eur11_df.drop(
    cordex_eur11_df[
        (cordex_eur11_df["driving_model_id"] == "ICHEC-EC-EARTH") &
        (cordex_eur11_df["member"] == "r1i1p1")
    ].index
)

# %%
# replace URI to path to downloaded data
cordex_eur11_df["uri"] = (
    DATA_DIR_BASE + os.sep +
    cordex_eur11_df["institute_id"] + os.sep +
    cordex_eur11_df["experiment_id"] + os.sep +
    cordex_eur11_df["variable_id"] + os.sep +
    cordex_eur11_df["uri"].str.split("/").str[-1]
)

cordex_eur11_df["path"] = cordex_eur11_df["uri"]

# %%
cordex_eur11_df.head()
# Out:
#   project product_id CORDEX_domain institute_id       driving_model_id  \
# 0  CORDEX     output        EUR-11         SMHI  CNRM-CERFACS-CNRM-CM5
# 1  CORDEX     output        EUR-11         SMHI  CNRM-CERFACS-CNRM-CM5
# 2  CORDEX     output        EUR-11         SMHI  CNRM-CERFACS-CNRM-CM5
# 3  CORDEX     output        EUR-11         SMHI  CNRM-CERFACS-CNRM-CM5
# 4  CORDEX     output        EUR-11         SMHI  CNRM-CERFACS-CNRM-CM5
#
#   experiment_id  member   model_id rcm_version_id frequency  ... grid_label  \
# 0    historical  r1i1p1  SMHI-RCA4             v1       day  ...       None
# 1    historical  r1i1p1  SMHI-RCA4             v1       day  ...       None
# 2    historical  r1i1p1  SMHI-RCA4             v1       day  ...       None
# 3    historical  r1i1p1  SMHI-RCA4             v1       day  ...       None
# 4    historical  r1i1p1  SMHI-RCA4             v1       day  ...       None
#
#   grid_id time_reduction realm level_type  time_min  time_max  \
# 0    None           None  None       None  19760101  19801231
# 1    None           None  None       None  19810101  19851231
# 2    None           None  None       None  19860101  19901231
# 3    None           None  None       None  19910101  19951231
# 4    None           None  None       None  19960101  20001231
#
#                                                 path  format  \
# 0  data/eurocordex/SMHI/historical/evspsblpot/evs...  netcdf
# 1  data/eurocordex/SMHI/historical/evspsblpot/evs...  netcdf
# 2  data/eurocordex/SMHI/historical/evspsblpot/evs...  netcdf
# 3  data/eurocordex/SMHI/historical/evspsblpot/evs...  netcdf
# 4  data/eurocordex/SMHI/historical/evspsblpot/evs...  netcdf
#
#                                          opendap_url
# 0  http://esgf1.dkrz.de/thredds/dodsC/cordex/EUR-...
# 1  http://esgf1.dkrz.de/thredds/dodsC/cordex/EUR-...
# 2  http://esgf1.dkrz.de/thredds/dodsC/cordex/EUR-...
# 3  http://esgf1.dkrz.de/thredds/dodsC/cordex/EUR-...
# 4  http://esgf1.dkrz.de/thredds/dodsC/cordex/EUR-...
#
# [5 rows x 27 columns]

# %%
cordex_eur11_df.shape
# Out:
# (360, 27)

# %%
CSV_FILE_PATH = os.path.join(DATA_DIR_BASE, "eurocordex_eur11_catalogue.csv")

# %%
cordex_eur11_df.to_csv(CSV_FILE_PATH, index=False)

# %%
JSON_FILE_PATH = os.path.join(DATA_DIR_BASE, "dkrz_cordex_disk.json")

# %%
# modify the JSON catalogue
with open(JSON_FILE_PATH, encoding="utf-8") as json_file:
    cordex_eur11_cat = json.load(json_file)
    json_file.close()

# %%
GITHUB_CSV_LINK = (
    "https://raw.githubusercontent.com/ClimAg/data/main/eurocordex/"
    "eurocordex_eur11_catalogue.csv"
)

cordex_eur11_cat["catalog_file"] = GITHUB_CSV_LINK

# %%
cordex_eur11_cat["id"] = "eurocordex_eur11"

# %%
cordex_eur11_cat["description"] = (
    "This is an ESM collection for EURO-CORDEX data used in the ClimAg "
    "project. Data has been generated using the DKRZ intake-esm stores. "
    "Data is filtered for the EUR-11 CORDEX domain at the daily timescale, "
    "the historical (1976-2005) and future (rcp45, rcp85) (2041-2070) "
    "experiments, and the following variables: " + ", ".join(variables) +
    ". The SMHI-RCA4 RCM and four GCMs (" + ", ".join(driving_model_id) +
    ") are the models used to generate these data. Last updated: " +
    str(datetime.now(tz=timezone.utc)) + "."
)

# %%
# save the modified JSON file
JSON_FILE_PATH = os.path.join(DATA_DIR_BASE, "eurocordex_eur11_local.json")

# %%
with open(JSON_FILE_PATH, "w", encoding="utf-8") as json_file:
    json.dump(cordex_eur11_cat, json_file, ensure_ascii=False, indent=4)

# %%
# create a copy that reads the CSV file from disk
cordex_eur11_cat["catalog_file"] = CSV_FILE_PATH
JSON_FILE_PATH = os.path.join(
    DATA_DIR_BASE, "eurocordex_eur11_local_disk.json"
)
with open(JSON_FILE_PATH, "w", encoding="utf-8") as json_file:
    json.dump(cordex_eur11_cat, json_file, ensure_ascii=False, indent=4)

# %% [markdown]
# ## Testing the local catalogue

# %%
# JSON_FILE_PATH = (
#     "https://raw.githubusercontent.com/ClimAg/data/main/eurocordex/"
#     "eurocordex_eur11_local.json"
# )
JSON_FILE_PATH = os.path.join(
    DATA_DIR_BASE, "eurocordex_eur11_local_disk.json"
)

# %%
cordex_eur11_cat = intake.open_esm_datastore(JSON_FILE_PATH)

# %%
list(cordex_eur11_cat)
# Out:
# ['EUR-11.MPI-M-MPI-ESM-LR.SMHI.SMHI-RCA4.rcp85.day',
#  'EUR-11.MOHC-HadGEM2-ES.SMHI.SMHI-RCA4.historical.day',
#  'EUR-11.ICHEC-EC-EARTH.SMHI.SMHI-RCA4.rcp85.day',
#  'EUR-11.CNRM-CERFACS-CNRM-CM5.SMHI.SMHI-RCA4.rcp85.day',
#  'EUR-11.CNRM-CERFACS-CNRM-CM5.SMHI.SMHI-RCA4.rcp45.day',
#  'EUR-11.MPI-M-MPI-ESM-LR.SMHI.SMHI-RCA4.historical.day',
#  'EUR-11.MPI-M-MPI-ESM-LR.SMHI.SMHI-RCA4.rcp45.day',
#  'EUR-11.MOHC-HadGEM2-ES.SMHI.SMHI-RCA4.rcp85.day',
#  'EUR-11.MOHC-HadGEM2-ES.SMHI.SMHI-RCA4.rcp45.day',
#  'EUR-11.CNRM-CERFACS-CNRM-CM5.SMHI.SMHI-RCA4.historical.day',
#  'EUR-11.ICHEC-EC-EARTH.SMHI.SMHI-RCA4.historical.day',
#  'EUR-11.ICHEC-EC-EARTH.SMHI.SMHI-RCA4.rcp45.day']

# %%
cordex_eur11_cat
# Out:
# <p><strong>eurocordex_eur11 catalog with 12 dataset(s) from 432 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>project</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>product_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>CORDEX_domain</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>institute_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>driving_model_id</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>experiment_id</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>member</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>model_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>rcm_version_id</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>frequency</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>variable_id</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>version</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>time_range</th>
#       <td>24</td>
#     </tr>
#     <tr>
#       <th>uri</th>
#       <td>432</td>
#     </tr>
#     <tr>
#       <th>institution_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>source_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>simulation_id</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>grid_label</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>grid_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>time_reduction</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>realm</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>level_type</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>time_min</th>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>time_max</th>
#       <td>24</td>
#     </tr>
#     <tr>
#       <th>path</th>
#       <td>432</td>
#     </tr>
#     <tr>
#       <th>format</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>opendap_url</th>
#       <td>432</td>
#     </tr>
#     <tr>
#       <th>derived_variable_id</th>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
cordex_eur11_cat.df.shape
# Out:
# (432, 27)

# %%
cordex_eur11_cat.df.head()
# Out:
#   project product_id CORDEX_domain institute_id       driving_model_id  \
# 0  CORDEX     output        EUR-11         SMHI  CNRM-CERFACS-CNRM-CM5
# 1  CORDEX     output        EUR-11         SMHI  CNRM-CERFACS-CNRM-CM5
# 2  CORDEX     output        EUR-11         SMHI  CNRM-CERFACS-CNRM-CM5
# 3  CORDEX     output        EUR-11         SMHI  CNRM-CERFACS-CNRM-CM5
# 4  CORDEX     output        EUR-11         SMHI  CNRM-CERFACS-CNRM-CM5
#
#   experiment_id  member   model_id rcm_version_id frequency  ... grid_label  \
# 0    historical  r1i1p1  SMHI-RCA4             v1       day  ...       None
# 1    historical  r1i1p1  SMHI-RCA4             v1       day  ...       None
# 2    historical  r1i1p1  SMHI-RCA4             v1       day  ...       None
# 3    historical  r1i1p1  SMHI-RCA4             v1       day  ...       None
# 4    historical  r1i1p1  SMHI-RCA4             v1       day  ...       None
#
#   grid_id time_reduction realm level_type  time_min  time_max  \
# 0    None           None  None       None  19760101  19801231
# 1    None           None  None       None  19810101  19851231
# 2    None           None  None       None  19860101  19901231
# 3    None           None  None       None  19910101  19951231
# 4    None           None  None       None  19960101  20001231
#
#                                                 path  format  \
# 0  data/eurocordex/SMHI/historical/evspsblpot/evs...  netcdf
# 1  data/eurocordex/SMHI/historical/evspsblpot/evs...  netcdf
# 2  data/eurocordex/SMHI/historical/evspsblpot/evs...  netcdf
# 3  data/eurocordex/SMHI/historical/evspsblpot/evs...  netcdf
# 4  data/eurocordex/SMHI/historical/evspsblpot/evs...  netcdf
#
#                                          opendap_url
# 0  http://esgf1.dkrz.de/thredds/dodsC/cordex/EUR-...
# 1  http://esgf1.dkrz.de/thredds/dodsC/cordex/EUR-...
# 2  http://esgf1.dkrz.de/thredds/dodsC/cordex/EUR-...
# 3  http://esgf1.dkrz.de/thredds/dodsC/cordex/EUR-...
# 4  http://esgf1.dkrz.de/thredds/dodsC/cordex/EUR-...
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Read a subset (precipitation)

# %%
# filter data subset
query = dict(
    experiment_id="rcp85",
    variable_id="pr",
    driving_model_id="MPI-M-MPI-ESM-LR",
)

# %%
cordex_eur11_pr = cordex_eur11_cat.search(**query)

# %%
cordex_eur11_pr
# Out:
# <p><strong>eurocordex_eur11 catalog with 1 dataset(s) from 6 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>project</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>product_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>CORDEX_domain</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>institute_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>driving_model_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>experiment_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>member</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>model_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>rcm_version_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>frequency</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>variable_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>version</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>time_range</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>uri</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>institution_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>source_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>simulation_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>grid_label</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>grid_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>time_reduction</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>realm</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>level_type</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>time_min</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>time_max</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>path</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>format</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>opendap_url</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>derived_variable_id</th>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
cordex_eur11_pr.df
# Out:
#   project product_id CORDEX_domain institute_id  driving_model_id  \
# 0  CORDEX     output        EUR-11         SMHI  MPI-M-MPI-ESM-LR
# 1  CORDEX     output        EUR-11         SMHI  MPI-M-MPI-ESM-LR
# 2  CORDEX     output        EUR-11         SMHI  MPI-M-MPI-ESM-LR
# 3  CORDEX     output        EUR-11         SMHI  MPI-M-MPI-ESM-LR
# 4  CORDEX     output        EUR-11         SMHI  MPI-M-MPI-ESM-LR
# 5  CORDEX     output        EUR-11         SMHI  MPI-M-MPI-ESM-LR
#
#   experiment_id  member   model_id rcm_version_id frequency  ... grid_label  \
# 0         rcp85  r1i1p1  SMHI-RCA4            v1a       day  ...       None
# 1         rcp85  r1i1p1  SMHI-RCA4            v1a       day  ...       None
# 2         rcp85  r1i1p1  SMHI-RCA4            v1a       day  ...       None
# 3         rcp85  r1i1p1  SMHI-RCA4            v1a       day  ...       None
# 4         rcp85  r1i1p1  SMHI-RCA4            v1a       day  ...       None
# 5         rcp85  r1i1p1  SMHI-RCA4            v1a       day  ...       None
#
#   grid_id time_reduction realm level_type  time_min  time_max  \
# 0    None           None  None       None  20410101  20451231
# 1    None           None  None       None  20460101  20501231
# 2    None           None  None       None  20510101  20551231
# 3    None           None  None       None  20560101  20601231
# 4    None           None  None       None  20610101  20651231
# 5    None           None  None       None  20660101  20701231
#
#                                                 path  format  \
# 0  data/eurocordex/SMHI/rcp85/pr/pr_EUR-11_MPI-M-...  netcdf
# 1  data/eurocordex/SMHI/rcp85/pr/pr_EUR-11_MPI-M-...  netcdf
# 2  data/eurocordex/SMHI/rcp85/pr/pr_EUR-11_MPI-M-...  netcdf
# 3  data/eurocordex/SMHI/rcp85/pr/pr_EUR-11_MPI-M-...  netcdf
# 4  data/eurocordex/SMHI/rcp85/pr/pr_EUR-11_MPI-M-...  netcdf
# 5  data/eurocordex/SMHI/rcp85/pr/pr_EUR-11_MPI-M-...  netcdf
#
#                                          opendap_url
# 0  http://esgf1.dkrz.de/thredds/dodsC/cordex/EUR-...
# 1  http://esgf1.dkrz.de/thredds/dodsC/cordex/EUR-...
# 2  http://esgf1.dkrz.de/thredds/dodsC/cordex/EUR-...
# 3  http://esgf1.dkrz.de/thredds/dodsC/cordex/EUR-...
# 4  http://esgf1.dkrz.de/thredds/dodsC/cordex/EUR-...
# 5  http://esgf1.dkrz.de/thredds/dodsC/cordex/EUR-...
#
# [6 rows x 27 columns]

# %%
pr = cordex_eur11_pr.to_dataset_dict()
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'CORDEX_domain.driving_model_id.institute_id.model_id.experiment_id.frequency'
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='1' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1/1 00:00&lt;00:00]
#     </div>

# %%
pr = pr.popitem()[1]

# %%
pr
# Out:
# <xarray.Dataset>
# Dimensions:       (rlat: 412, rlon: 424, member: 1, time: 10957, bnds: 2)
# Coordinates:
#     lat           (rlat, rlon) float64 dask.array<chunksize=(412, 424), meta=np.ndarray>
#     lon           (rlat, rlon) float64 dask.array<chunksize=(412, 424), meta=np.ndarray>
#   * rlat          (rlat) float64 -23.38 -23.27 -23.16 ... 21.62 21.73 21.84
#   * rlon          (rlon) float64 -28.38 -28.27 -28.16 ... 17.94 18.05 18.16
#     rotated_pole  |S1 b''
#   * time          (time) datetime64[ns] 2041-01-01T12:00:00 ... 2070-12-31T12...
#     time_bnds     (time, bnds) datetime64[ns] dask.array<chunksize=(1826, 2), meta=np.ndarray>
#   * member        (member) object 'r1i1p1'
# Dimensions without coordinates: bnds
# Data variables:
#     pr            (member, time, rlat, rlon) float32 dask.array<chunksize=(1, 1826, 412, 424), meta=np.ndarray>
# Attributes: (12/43)
#     Conventions:                        CF-1.4
#     contact:                            rossby.cordex@smhi.se
#     experiment:                         RCP85
#     experiment_id:                      rcp85
#     driving_experiment:                 MPI-M-MPI-ESM-LR, rcp85, r1i1p1
#     driving_model_id:                   MPI-M-MPI-ESM-LR
#     ...                                 ...
#     intake_esm_attrs:grid_id:           None
#     intake_esm_attrs:time_reduction:    None
#     intake_esm_attrs:realm:             None
#     intake_esm_attrs:level_type:        None
#     intake_esm_attrs:_data_format_:     netcdf
#     intake_esm_dataset_key:             EUR-11.MPI-M-MPI-ESM-LR.SMHI.SMHI-RCA...

# %%
# read one of the data files to extract CRS info
data_ec = xr.open_dataset(
    cordex_eur11_pr.df["uri"][0], decode_coords="all", chunks=True
)

# %%
pr.rio.write_crs(data_ec.rio.crs, inplace=True)
# Out:
# <xarray.Dataset>
# Dimensions:       (rlat: 412, rlon: 424, member: 1, time: 10957, bnds: 2)
# Coordinates:
#     lat           (rlat, rlon) float64 dask.array<chunksize=(412, 424), meta=np.ndarray>
#     lon           (rlat, rlon) float64 dask.array<chunksize=(412, 424), meta=np.ndarray>
#   * rlat          (rlat) float64 -23.38 -23.27 -23.16 ... 21.62 21.73 21.84
#   * rlon          (rlon) float64 -28.38 -28.27 -28.16 ... 17.94 18.05 18.16
#   * time          (time) datetime64[ns] 2041-01-01T12:00:00 ... 2070-12-31T12...
#     time_bnds     (time, bnds) datetime64[ns] dask.array<chunksize=(1826, 2), meta=np.ndarray>
#   * member        (member) object 'r1i1p1'
#     rotated_pole  int64 0
# Dimensions without coordinates: bnds
# Data variables:
#     pr            (member, time, rlat, rlon) float32 dask.array<chunksize=(1, 1826, 412, 424), meta=np.ndarray>
# Attributes: (12/43)
#     Conventions:                        CF-1.4
#     contact:                            rossby.cordex@smhi.se
#     experiment:                         RCP85
#     experiment_id:                      rcp85
#     driving_experiment:                 MPI-M-MPI-ESM-LR, rcp85, r1i1p1
#     driving_model_id:                   MPI-M-MPI-ESM-LR
#     ...                                 ...
#     intake_esm_attrs:grid_id:           None
#     intake_esm_attrs:time_reduction:    None
#     intake_esm_attrs:realm:             None
#     intake_esm_attrs:level_type:        None
#     intake_esm_attrs:_data_format_:     netcdf
#     intake_esm_dataset_key:             EUR-11.MPI-M-MPI-ESM-LR.SMHI.SMHI-RCA...

# %% [markdown]
# ### Time subset

# %%
pr_50 = pr.sel(time="2055-06-21T12:00:00.000000000")

# %%
plot_transform = cplt.rotated_pole_transform(pr_50)
data_var = pr_50["pr"]  # variable name
plot_data = data_var * 60 * 60 * 24  # convert to mm/day
cbar_label = data_var.attrs["long_name"] + " [mm/day]"  # colorbar label

plt.figure(figsize=(20, 10))
ax = plt.axes(projection=plot_transform)

# specify gridline spacing and labels
ax.gridlines(
    draw_labels=True,
    xlocs=range(-180, 180, 10),
    ylocs=range(-90, 90, 5),
    color="lightslategrey",
    linewidth=.5
)

# plot data for the variable
plot_data.plot(
    ax=ax,
    cmap="GnBu",
    transform=plot_transform,
    x="rlon",
    y="rlat",
    cbar_kwargs=dict(label=cbar_label)
)

# add boundaries
ax.coastlines(resolution="50m", color="darkslategrey", linewidth=.5)

ax.set_title(cplt.cordex_plot_title(pr_50))  # set plot title

plt.show()

# %% [markdown]
# ### Point subset

# %%
cds = cplt.rotated_pole_point(data=pr, lon=LON, lat=LAT)

# %%
pr_ca = pr.sel({"rlon": cds[0], "rlat": cds[1]}, method="nearest")

# %%
plt.figure(figsize=(12, 4))
plt.plot(
    pr_ca["time"],
    pr_ca["pr"].values[0] * 60 * 60 * 24
)
plt.xlabel(pr_ca["time"].attrs["standard_name"])
plt.ylabel(pr_ca["pr"].attrs["long_name"] + " [mm/day]")
plt.title(cplt.cordex_plot_title(pr_ca, lon=LON, lat=LAT))
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Ireland subset

# %%
# clip to Ireland's boundary
pr_ie = pr_50.rio.clip(ie.buffer(1).to_crs(pr_50.rio.crs))

# %%
plot_transform = cplt.rotated_pole_transform(pr_ie)
data_var = pr_ie["pr"]  # extract variable name
plot_data = data_var * 60 * 60 * 24  # convert to mm/day
cbar_label = data_var.attrs["long_name"] + " [mm/day]"  # colorbar label

plt.figure(figsize=(20, 10))
ax = plt.axes(projection=plot_transform)

# specify gridline spacing and labels
ax.gridlines(
    draw_labels=True,
    xlocs=range(-180, 180, 2),
    ylocs=range(-90, 90, 1),
    color="lightslategrey",
    linewidth=.5
)

# plot data for the variable
plot_data.plot(
    ax=ax,
    cmap="GnBu",
    transform=plot_transform,
    x="rlon",
    y="rlat",
    cbar_kwargs=dict(label=cbar_label)
)

# add boundaries
ax.coastlines(resolution="10m", color="darkslategrey", linewidth=.75)

ax.set_title(cplt.cordex_plot_title(pr_ie))  # set plot title

plt.show()
