# %% [markdown]
# # ModVege results - EURO-CORDEX - Difference in min - historical and observational (MÉRA)

# %%
# import libraries
import glob
import os
from datetime import datetime, timezone
import geopandas as gpd
import matplotlib.pyplot as plt
import rasterio as rio
import xarray as xr
import climag.plot_configs as cplt
import climag.plot_stats as cstats
import importlib

# %%
season_list = ["DJF", "MAM", "JJA", "SON"]

# %%
data = cstats.hist_obs_diff(stat="min", dataset="EURO-CORDEX")

# %%
importlib.reload(cstats)
# Out:
# <module 'climag.plot_stats' from '/run/media/nms/Backup/Documents/Git/ClimAg/ClimAg/climag/plot_stats.py'>

# %% [markdown]
# ## Total growth (daily)

# %%
for season in season_list:
    cstats.plot_obs_diff_all(
        data=data["MERA_s_diff"], var="gro", season=season,
        levels=cstats.colorbar_levels(15),
        ticks=cstats.colorbar_ticks(15)
    )
# Out:
# ________________________________________________________________________________
# Difference in average total growth from MÉRA-driven simulations for EURO-CORDEX
# DJF, 1981-2005
# ________________________________________________________________________________
# ________________________________________________________________________________
# Difference in average total growth from MÉRA-driven simulations for EURO-CORDEX
# MAM, 1981-2005
# ________________________________________________________________________________
# ________________________________________________________________________________
# Difference in average total growth from MÉRA-driven simulations for EURO-CORDEX
# JJA, 1981-2005
# ________________________________________________________________________________
# ________________________________________________________________________________
# Difference in average total growth from MÉRA-driven simulations for EURO-CORDEX
# SON, 1981-2005
# ________________________________________________________________________________

# %% [markdown]
# ## Potential growth (daily)

# %%
for season in season_list:
    cstats.plot_obs_diff_all(
        data=data["MERA_s_diff"], var="pgro", season=season,
        levels=cstats.colorbar_levels(32),
        ticks=cstats.colorbar_ticks(32)
    )
# Out:
# ________________________________________________________________________________
# Difference in average potential growth from MÉRA-driven simulations for EURO-CORDEX
# DJF, 1981-2005
# ________________________________________________________________________________
# ________________________________________________________________________________
# Difference in average potential growth from MÉRA-driven simulations for EURO-CORDEX
# MAM, 1981-2005
# ________________________________________________________________________________
# ________________________________________________________________________________
# Difference in average potential growth from MÉRA-driven simulations for EURO-CORDEX
# JJA, 1981-2005
# ________________________________________________________________________________
# ________________________________________________________________________________
# Difference in average potential growth from MÉRA-driven simulations for EURO-CORDEX
# SON, 1981-2005
# ________________________________________________________________________________

# %% [markdown]
# ## Total ingestion (daily)

# %%
for season in season_list:
    cstats.plot_obs_diff_all(
        data=data["MERA_s_diff"], var="c_bm", season=season,
        levels=cstats.colorbar_levels(22.5),
        ticks=cstats.colorbar_ticks(22.5)
    )
# Out:
# ________________________________________________________________________________
# Difference in average ingested biomass from MÉRA-driven simulations for EURO-CORDEX
# DJF, 1981-2005
# ________________________________________________________________________________
# ________________________________________________________________________________
# Difference in average ingested biomass from MÉRA-driven simulations for EURO-CORDEX
# MAM, 1981-2005
# ________________________________________________________________________________
# ________________________________________________________________________________
# Difference in average ingested biomass from MÉRA-driven simulations for EURO-CORDEX
# JJA, 1981-2005
# ________________________________________________________________________________
# ________________________________________________________________________________
# Difference in average ingested biomass from MÉRA-driven simulations for EURO-CORDEX
# SON, 1981-2005
# ________________________________________________________________________________

# %% [markdown]
# ## Standing biomass (cumulative)

# %%
for season in season_list:
    cstats.plot_obs_diff_all(
        data=data["MERA_s_diff"], var="bm", season=season,
        levels=cstats.colorbar_levels(1250),
        ticks=cstats.colorbar_ticks(1250)
    )
# Out:
# ________________________________________________________________________________
# Difference in average standing biomass from MÉRA-driven simulations for EURO-CORDEX
# DJF, 1981-2005
# ________________________________________________________________________________
# ________________________________________________________________________________
# Difference in average standing biomass from MÉRA-driven simulations for EURO-CORDEX
# MAM, 1981-2005
# ________________________________________________________________________________
# ________________________________________________________________________________
# Difference in average standing biomass from MÉRA-driven simulations for EURO-CORDEX
# JJA, 1981-2005
# ________________________________________________________________________________
# ________________________________________________________________________________
# Difference in average standing biomass from MÉRA-driven simulations for EURO-CORDEX
# SON, 1981-2005
# ________________________________________________________________________________

# %% [markdown]
# ## Defoliation (senescence + abscission) (daily)

# %%
for season in season_list:
    cstats.plot_obs_diff_all(
        data=data["MERA_s_diff"], var="sen_abs", season=season,
        levels=cstats.colorbar_levels(30),
        ticks=cstats.colorbar_ticks(30)
    )
# Out:
# ________________________________________________________________________________
# Difference in average defoliation from MÉRA-driven simulations for EURO-CORDEX
# DJF, 1981-2005
# ________________________________________________________________________________
# ________________________________________________________________________________
# Difference in average defoliation from MÉRA-driven simulations for EURO-CORDEX
# MAM, 1981-2005
# ________________________________________________________________________________
# ________________________________________________________________________________
# Difference in average defoliation from MÉRA-driven simulations for EURO-CORDEX
# JJA, 1981-2005
# ________________________________________________________________________________
# ________________________________________________________________________________
# Difference in average defoliation from MÉRA-driven simulations for EURO-CORDEX
# SON, 1981-2005
# ________________________________________________________________________________

# %% [markdown]
# ## Total biomass consumption (ingested + harvested) (yearly total)

# %%
cstats.plot_obs_diff_all(
    data=data["MERA_c_diff"], var="c_bm_all", season=None,
    levels=cstats.colorbar_levels(3200),
    ticks=cstats.colorbar_ticks(3200)
)
# Out:
# ________________________________________________________________________________
# Difference in average yearly ingested and harvested biomass from MÉRA-driven simulations for EURO-CORDEX
# 1981-2005
# ________________________________________________________________________________

# %%
print("Last updated:", datetime.now(tz=timezone.utc))
# Out:
# Last updated: 2023-04-14 18:57:17.011884+00:00
